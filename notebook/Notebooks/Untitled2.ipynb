# %%
import iris
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import iris
#
# File /opt/conda/lib/python3.11/site-packages/iris/__init__.py:18
#      15 # also append lib/python
#      16 __syspath.append(os.path.join(installdir, 'lib', 'python'))
# ---> 18 from pythonint import *
#      20 # TODO: Figure out how to hide __syspath and __ospath from anyone that
#      21 #       imports iris.  Tried __all__ but that only applies to this:
#      22 #           from iris import *
#    (...)
#      25 # End-of-file
#      26 #
#
# ModuleNotFoundError: No module named 'pythonint'
